# %%
import numpy as np
import matplotlib.pyplot as plt
fig1 = plt.figure(1, figsize=(12, 8), dpi=120)

X = np.linspace(0,10,10000)
mysin = np.sin(X)
mycos = np.cos(X)

fig=plt.figure(1)
plt.subplot(221)
plt.plot(X,mysin)
plt.plot(X,mycos)
plt.subplot(222)
plt.plot(X,mycos)
plt.show()
